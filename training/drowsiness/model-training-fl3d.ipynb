# %%
import os, sys
import glob

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import tensorflow as tf
import keras

# %%
print(f"Keras version: {keras.__version__}")
print(f"TensorFlow version: {tf.__version__}")
# Out:
# Keras version: 3.11.3
# TensorFlow version: 2.20.0

# %%
RANDOM_STATE = 42
IMAGE_SHAPE = (48, 48)
INPUT_SHAPE = (48, 48, 1)
EPOCHS = 100
BATCH_SIZE = 32
NUM_CLASSES = 3

# %%
os.getcwd()
# Out:
# '/Users/rishijaiswal/Downloads/project code'

# %%
os.listdir("../../data")
# Out:
# ['.DS_Store', 'test', 'train', 'val']

# %%
os.listdir("/Users/rishijaiswal/Downloads/project code/data/train")
# Out:
# ['.DS_Store', 'alert', 'yawning', 'microsleep']

# %%
train_path = r'/Users/rishijaiswal/Downloads/project code/data/train'
val_path = r'/Users/rishijaiswal/Downloads/project code/data/val'
test_path = r'/Users/rishijaiswal/Downloads/project code/data/test'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# augmenting images for training set
datagen = ImageDataGenerator(
    rescale = 1./255, 
    rotation_range = 15, 
    width_shift_range = 10,
    height_shift_range = 10, 
    shear_range = 0.15,
    zoom_range = 0.15,
    horizontal_flip = True,
)

# only normalizing the pixel values for the testing set
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# read the data from directory 
train_gen = datagen.flow_from_directory(
    train_path, 
    target_size = IMAGE_SHAPE,
    batch_size = BATCH_SIZE, 
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle = True
)

val_gen = datagen.flow_from_directory(
    val_path, 
    target_size = IMAGE_SHAPE,
    batch_size = BATCH_SIZE, 
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle = True
)

test_gen = test_datagen.flow_from_directory(
    test_path, 
    target_size = IMAGE_SHAPE,
    batch_size = BATCH_SIZE, 
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle = False,
)
# Out:
# Found 48327 images belonging to 3 classes.
# Found 2502 images belonging to 3 classes.
# Found 2502 images belonging to 3 classes.

# %%
classes = ['alert', 'microsleep', 'yawning']

# %%
class_count = np.unique(train_gen.classes, return_counts = True)

print("Class", class_count[0])
print("Count", class_count[1])
print()

plt.figure()

sns.barplot(x = classes, y = class_count[1])

plt.title("Training set is imbalance")
plt.xlabel('class')
plt.ylabel('count') 
plt.show()
# Out:
# Class [0 1 2]
# Count [35483  8074  4770]

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_gen.classes),
    y=train_gen.classes
)
class_labels = np.unique(train_gen.classes)
class_weight_dict = dict(zip(class_labels, class_weights))
class_weights
# Out:
# array([0.45399205, 1.99516968, 3.37714885])

# %%
class_weight_dict
# Out:
# {np.int32(0): np.float64(0.45399205253219854),
#  np.int32(1): np.float64(1.995169680455784),
#  np.int32(2): np.float64(3.377148846960168)}

# %%
fig, axes = plt.subplots(ncols = 5, nrows = 5)
axes =axes.flatten()

for i in range(25):
    j = np.random.randint(train_gen.n)

    # take data 
    batch_images, batch_labels = train_gen[j // BATCH_SIZE]
    id_in_batch = j % BATCH_SIZE 
    image = batch_images[id_in_batch]
    label = batch_labels[id_in_batch].argmax()

    # show data
    axes[i].imshow(image, cmap = "gray")
    axes[i].set_title(classes[label])
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(48,48,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.SpatialDropout2D(0.2),
    
    keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.SpatialDropout2D(0.2),
    
    keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.SpatialDropout2D(0.2),
    
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(3, activation='softmax')
])

optimizer = keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-4)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# /Users/rishijaiswal/Downloads/project code/venv/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d               │ (None, 24, 24, 32)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_1             │ (None, 12, 12, 64)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_2             │ (None, 6, 6, 128)      │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 489,443 (1.87 MB)
#  Trainable params: 487,011 (1.86 MB)
#  Non-trainable params: 2,432 (9.50 KB)

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
callbacks = [early_stopping, lr_scheduler]

# %%
model.fit(train_gen, epochs=100, validation_data=val_gen,class_weight=class_weight_dict, callbacks = callbacks)
# Out:
# Epoch 1/100
# /Users/rishijaiswal/Downloads/project code/venv/lib/python3.13/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 308s 200ms/step - accuracy: 0.6143 - loss: 0.6902 - val_accuracy: 0.8537 - val_loss: 0.3623 - learning_rate: 0.0010
# Epoch 2/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 279s 184ms/step - accuracy: 0.8339 - loss: 0.3194 - val_accuracy: 0.9305 - val_loss: 0.2097 - learning_rate: 0.0010
# Epoch 3/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 277s 183ms/step - accuracy: 0.9105 - loss: 0.1933 - val_accuracy: 0.9269 - val_loss: 0.1816 - learning_rate: 0.0010
# Epoch 4/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 277s 183ms/step - accuracy: 0.9281 - loss: 0.1520 - val_accuracy: 0.9225 - val_loss: 0.2203 - learning_rate: 0.0010
# Epoch 5/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 276s 183ms/step - accuracy: 0.9398 - loss: 0.1283 - val_accuracy: 0.9388 - val_loss: 0.1615 - learning_rate: 0.0010
# Epoch 6/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 291s 193ms/step - accuracy: 0.9437 - loss: 0.1193 - val_accuracy: 0.9305 - val_loss: 0.1776 - learning_rate: 0.0010
# Epoch 7/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 274s 182ms/step - accuracy: 0.9484 - loss: 0.1127 - val_accuracy: 0.9033 - val_loss: 0.3192 - learning_rate: 0.0010
# Epoch 8/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 276s 183ms/step - accuracy: 0.9482 - loss: 0.1062 - val_accuracy: 0.9285 - val_loss: 0.1691 - learning_rate: 0.0010
# Epoch 9/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 278s 184ms/step - accuracy: 0.9572 - loss: 0.0897 - val_accuracy: 0.9624 - val_loss: 0.0996 - learning_rate: 0.0010
# Epoch 10/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 297s 197ms/step - accuracy: 0.9588 - loss: 0.0874 - val_accuracy: 0.9548 - val_loss: 0.1382 - learning_rate: 0.0010
# Epoch 11/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 283s 187ms/step - accuracy: 0.9630 - loss: 0.0779 - val_accuracy: 0.9584 - val_loss: 0.1049 - learning_rate: 0.0010
# Epoch 12/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 280s 185ms/step - accuracy: 0.9595 - loss: 0.0821 - val_accuracy: 0.9680 - val_loss: 0.0863 - learning_rate: 0.0010
# Epoch 13/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 281s 186ms/step - accuracy: 0.9622 - loss: 0.0789 - val_accuracy: 0.9512 - val_loss: 0.1445 - learning_rate: 0.0010
# Epoch 14/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 283s 188ms/step - accuracy: 0.9645 - loss: 0.0772 - val_accuracy: 0.9408 - val_loss: 0.1478 - learning_rate: 0.0010
# Epoch 15/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 285s 188ms/step - accuracy: 0.9681 - loss: 0.0665 - val_accuracy: 0.9572 - val_loss: 0.1126 - learning_rate: 0.0010
# Epoch 16/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 286s 189ms/step - accuracy: 0.9664 - loss: 0.0696 - val_accuracy: 0.9704 - val_loss: 0.0772 - learning_rate: 0.0010
# Epoch 17/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 291s 193ms/step - accuracy: 0.9674 - loss: 0.0678 - val_accuracy: 0.9628 - val_loss: 0.0915 - learning_rate: 0.0010
# Epoch 18/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 280s 185ms/step - accuracy: 0.9688 - loss: 0.0637 - val_accuracy: 0.9720 - val_loss: 0.0744 - learning_rate: 0.0010
# Epoch 19/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 278s 184ms/step - accuracy: 0.9685 - loss: 0.0634 - val_accuracy: 0.9532 - val_loss: 0.1224 - learning_rate: 0.0010
# Epoch 20/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 280s 185ms/step - accuracy: 0.9703 - loss: 0.0615 - val_accuracy: 0.9716 - val_loss: 0.0734 - learning_rate: 0.0010
# Epoch 21/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 283s 187ms/step - accuracy: 0.9693 - loss: 0.0620 - val_accuracy: 0.9668 - val_loss: 0.0865 - learning_rate: 0.0010
# Epoch 22/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 333s 220ms/step - accuracy: 0.9707 - loss: 0.0601 - val_accuracy: 0.9640 - val_loss: 0.0979 - learning_rate: 0.0010
# Epoch 23/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 280s 185ms/step - accuracy: 0.9730 - loss: 0.0563 - val_accuracy: 0.9544 - val_loss: 0.1107 - learning_rate: 0.0010
# Epoch 24/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 152s 101ms/step - accuracy: 0.9717 - loss: 0.0598 - val_accuracy: 0.8042 - val_loss: 0.6958 - learning_rate: 0.0010
# Epoch 25/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 180s 119ms/step - accuracy: 0.9722 - loss: 0.0598 - val_accuracy: 0.9708 - val_loss: 0.0718 - learning_rate: 0.0010
# Epoch 26/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 280s 185ms/step - accuracy: 0.9723 - loss: 0.0561 - val_accuracy: 0.9660 - val_loss: 0.0894 - learning_rate: 0.0010
# Epoch 27/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 288s 190ms/step - accuracy: 0.9729 - loss: 0.0544 - val_accuracy: 0.9648 - val_loss: 0.0790 - learning_rate: 0.0010
# Epoch 28/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 292s 194ms/step - accuracy: 0.9741 - loss: 0.0517 - val_accuracy: 0.9736 - val_loss: 0.0656 - learning_rate: 0.0010
# Epoch 29/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 307s 203ms/step - accuracy: 0.9743 - loss: 0.0541 - val_accuracy: 0.9644 - val_loss: 0.0911 - learning_rate: 0.0010
# Epoch 30/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 282s 187ms/step - accuracy: 0.9739 - loss: 0.0526 - val_accuracy: 0.9656 - val_loss: 0.0848 - learning_rate: 0.0010
# Epoch 31/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 290s 192ms/step - accuracy: 0.9744 - loss: 0.0512 - val_accuracy: 0.9500 - val_loss: 0.1171 - learning_rate: 0.0010
# Epoch 32/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 375s 248ms/step - accuracy: 0.9743 - loss: 0.0531 - val_accuracy: 0.9548 - val_loss: 0.1079 - learning_rate: 0.0010
# Epoch 33/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9765 - loss: 0.0486
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 281s 186ms/step - accuracy: 0.9759 - loss: 0.0486 - val_accuracy: 0.9632 - val_loss: 0.0861 - learning_rate: 0.0010
# Epoch 34/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 279s 185ms/step - accuracy: 0.9773 - loss: 0.0449 - val_accuracy: 0.9760 - val_loss: 0.0738 - learning_rate: 5.0000e-04
# Epoch 35/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 259s 171ms/step - accuracy: 0.9785 - loss: 0.0427 - val_accuracy: 0.9664 - val_loss: 0.0922 - learning_rate: 5.0000e-04
# Epoch 36/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 153s 101ms/step - accuracy: 0.9791 - loss: 0.0411 - val_accuracy: 0.9760 - val_loss: 0.0624 - learning_rate: 5.0000e-04
# Epoch 37/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 148s 98ms/step - accuracy: 0.9786 - loss: 0.0432 - val_accuracy: 0.9740 - val_loss: 0.0703 - learning_rate: 5.0000e-04
# Epoch 38/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 145s 96ms/step - accuracy: 0.9789 - loss: 0.0427 - val_accuracy: 0.9716 - val_loss: 0.0747 - learning_rate: 5.0000e-04
# Epoch 39/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 165s 109ms/step - accuracy: 0.9803 - loss: 0.0378 - val_accuracy: 0.9760 - val_loss: 0.0695 - learning_rate: 5.0000e-04
# Epoch 40/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 168s 111ms/step - accuracy: 0.9794 - loss: 0.0398 - val_accuracy: 0.9700 - val_loss: 0.0729 - learning_rate: 5.0000e-04
# Epoch 41/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9799 - loss: 0.0386
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 181s 120ms/step - accuracy: 0.9802 - loss: 0.0379 - val_accuracy: 0.9716 - val_loss: 0.0795 - learning_rate: 5.0000e-04
# Epoch 42/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 164s 108ms/step - accuracy: 0.9811 - loss: 0.0349 - val_accuracy: 0.9696 - val_loss: 0.0772 - learning_rate: 2.5000e-04
# Epoch 43/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 149s 99ms/step - accuracy: 0.9819 - loss: 0.0354 - val_accuracy: 0.9728 - val_loss: 0.0665 - learning_rate: 2.5000e-04
# Epoch 44/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 170s 113ms/step - accuracy: 0.9820 - loss: 0.0358 - val_accuracy: 0.9712 - val_loss: 0.0670 - learning_rate: 2.5000e-04
# Epoch 45/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 166s 110ms/step - accuracy: 0.9809 - loss: 0.0362 - val_accuracy: 0.9756 - val_loss: 0.0599 - learning_rate: 2.5000e-04
# Epoch 46/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 158s 105ms/step - accuracy: 0.9821 - loss: 0.0333 - val_accuracy: 0.9688 - val_loss: 0.0724 - learning_rate: 2.5000e-04
# Epoch 47/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 152s 101ms/step - accuracy: 0.9821 - loss: 0.0323 - val_accuracy: 0.9756 - val_loss: 0.0626 - learning_rate: 2.5000e-04
# Epoch 48/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 149s 99ms/step - accuracy: 0.9818 - loss: 0.0351 - val_accuracy: 0.9764 - val_loss: 0.0556 - learning_rate: 2.5000e-04
# Epoch 49/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 163s 108ms/step - accuracy: 0.9817 - loss: 0.0344 - val_accuracy: 0.9756 - val_loss: 0.0654 - learning_rate: 2.5000e-04
# Epoch 50/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 195s 128ms/step - accuracy: 0.9817 - loss: 0.0342 - val_accuracy: 0.9728 - val_loss: 0.0655 - learning_rate: 2.5000e-04
# Epoch 51/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 155s 103ms/step - accuracy: 0.9833 - loss: 0.0318 - val_accuracy: 0.9784 - val_loss: 0.0616 - learning_rate: 2.5000e-04
# Epoch 52/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 188s 124ms/step - accuracy: 0.9814 - loss: 0.0350 - val_accuracy: 0.9760 - val_loss: 0.0619 - learning_rate: 2.5000e-04
# Epoch 53/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9819 - loss: 0.0345
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 168s 111ms/step - accuracy: 0.9819 - loss: 0.0333 - val_accuracy: 0.9768 - val_loss: 0.0668 - learning_rate: 2.5000e-04
# Epoch 54/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 175s 116ms/step - accuracy: 0.9839 - loss: 0.0309 - val_accuracy: 0.9756 - val_loss: 0.0697 - learning_rate: 1.2500e-04
# Epoch 55/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 167s 111ms/step - accuracy: 0.9823 - loss: 0.0340 - val_accuracy: 0.9784 - val_loss: 0.0602 - learning_rate: 1.2500e-04
# Epoch 56/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 180s 119ms/step - accuracy: 0.9839 - loss: 0.0309 - val_accuracy: 0.9776 - val_loss: 0.0674 - learning_rate: 1.2500e-04
# Epoch 57/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 163s 108ms/step - accuracy: 0.9832 - loss: 0.0322 - val_accuracy: 0.9752 - val_loss: 0.0726 - learning_rate: 1.2500e-04
# Epoch 58/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9839 - loss: 0.0299
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 153s 101ms/step - accuracy: 0.9844 - loss: 0.0299 - val_accuracy: 0.9716 - val_loss: 0.0749 - learning_rate: 1.2500e-04
# Epoch 59/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 170s 112ms/step - accuracy: 0.9841 - loss: 0.0293 - val_accuracy: 0.9740 - val_loss: 0.0686 - learning_rate: 6.2500e-05
# Epoch 60/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 205s 135ms/step - accuracy: 0.9839 - loss: 0.0308 - val_accuracy: 0.9752 - val_loss: 0.0615 - learning_rate: 6.2500e-05
# Epoch 61/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 200s 133ms/step - accuracy: 0.9837 - loss: 0.0296 - val_accuracy: 0.9744 - val_loss: 0.0635 - learning_rate: 6.2500e-05
# Epoch 62/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 218s 144ms/step - accuracy: 0.9841 - loss: 0.0287 - val_accuracy: 0.9760 - val_loss: 0.0646 - learning_rate: 6.2500e-05
# Epoch 63/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9843 - loss: 0.0302
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 167s 111ms/step - accuracy: 0.9844 - loss: 0.0292 - val_accuracy: 0.9728 - val_loss: 0.0653 - learning_rate: 6.2500e-05

# %%
model.save('fl3d_model_3.keras')

# %%
model.save('fl3d_model_whts_3.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from IPython.display import FileLink

# Provide the path to your saved model file
file_path = "/kaggle/working/fl3d_model_3.keras"

# Create a downloadable link
FileLink(file_path)
# Out:
# /kaggle/working/fl3d_model_3.keras

# %%
# Provide the path to your saved model file
file_path_2 = "/kaggle/working/fl3d_model_whts_3.h5"

# Create a downloadable link
FileLink(file_path_2)
# Out:
# /kaggle/working/fl3d_model_whts_3.h5

# %%
score = model.evaluate(test_gen, verbose=1)
print(f"Test loss: {score[0]:.4f}")
print(f"Test accuracy: {score[1]:.4f}")
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9820 - loss: 0.0521
# Test loss: 0.0521
# Test accuracy: 0.9820

# %%
pred_y = model.predict(test_gen)
pred_label = np.argmax(pred_y, axis=1)

true_label = test_gen.classes
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
cfs_mt = confusion_matrix(true_label, pred_label)

plt.figure()

sns.heatmap(cfs_mt, annot = True, fmt = 'd')

plt.show()

# %%
print(classification_report(true_label, pred_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1728
#            1       0.97      0.94      0.96       416
#            2       0.98      0.99      0.99       358
#
#     accuracy                           0.98      2502
#    macro avg       0.98      0.98      0.98      2502
# weighted avg       0.98      0.98      0.98      2502

# %%
f1_scores = f1_score(true_label, pred_label, average=None)

f1_data = pd.DataFrame({
    'Class': classes,
    'F1-Score': f1_scores
})

# %%
f1_macro = f1_score(true_label, pred_label, average='macro')
print(f"F1-score macro: {f1_macro}")
# Out:
# F1-score macro: 0.9768734615266154

# %%
f1_data
# Out:
#         Class  F1-Score
# 0       alert  0.987005
# 1  microsleep  0.956098
# 2     yawning  0.987517

# %%
plt.figure()

sns.barplot(data=f1_data, x='Class', y='F1-Score')

plt.title('F1-Scores per Class')
plt.xticks(rotation=45)
plt.ylim(0, 1)

# add data label
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.01, f'{v:.3f}', ha='center')

plt.tight_layout()
plt.show()

# %%
# show 25 random test image and model predictions of them
fig, axes = plt.subplots(ncols = 5, nrows = 5, figsize = (15, 15))
axes =axes.flatten()

for i in range(25):
    j = np.random.randint(test_gen.n)

    # take data 
    batch_images, batch_labels = test_gen[j // BATCH_SIZE]
    id_in_batch = j % BATCH_SIZE 
    image = batch_images[id_in_batch]
    label = batch_labels[id_in_batch].argmax()

    # show data
    axes[i].imshow(image, cmap = "gray")
    axes[i].set_title(f"True label: {classes[label]}\nPredicted: {classes[pred_label[j]]}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()
