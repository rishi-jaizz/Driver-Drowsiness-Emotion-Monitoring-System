# %%
import os, sys
import glob

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import tensorflow as tf
import keras

# %%
print(f"Keras version: {keras.__version__}")
print(f"TensorFlow version: {tf.__version__}")
# Out:
# Keras version: 3.13.0
# TensorFlow version: 2.20.0

# %%
RANDOM_STATE = 42
IMAGE_SHAPE = (48, 48)
INPUT_SHAPE = (48, 48, 1)
EPOCHS = 100
BATCH_SIZE = 32
NUM_CLASSES = 3

# %%
os.getcwd()
# Out:
# '/Users/rishijaiswal/Downloads/Driver Drowsiness & Emotion Monitoring System/training/drowsiness'

# %%
os.listdir("../../data")
# Out:
# ['.DS_Store', 'emotion_dataset', 'drowsiness_dataset']

# %%
os.listdir("../../data/drowsiness_dataset/train")
# Out:
# ['.DS_Store', 'alert', 'yawning', 'microsleep']

# %%
train_path = r'../../data/drowsiness_dataset/train'
val_path = r'../../data/drowsiness_dataset/val'
test_path = r'../../data/drowsiness_dataset/test'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# augmenting images for training set
datagen = ImageDataGenerator(
    rescale = 1./255, 
    rotation_range = 15, 
    width_shift_range = 10,
    height_shift_range = 10, 
    shear_range = 0.15,
    zoom_range = 0.15,
    horizontal_flip = True,
)

# only normalizing the pixel values for the testing set
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# read the data from directory 
train_gen = datagen.flow_from_directory(
    train_path, 
    target_size = IMAGE_SHAPE,
    batch_size = BATCH_SIZE, 
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle = True
)

val_gen = datagen.flow_from_directory(
    val_path, 
    target_size = IMAGE_SHAPE,
    batch_size = BATCH_SIZE, 
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle = True
)

test_gen = test_datagen.flow_from_directory(
    test_path, 
    target_size = IMAGE_SHAPE,
    batch_size = BATCH_SIZE, 
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle = False,
)
# Out:
# Found 48327 images belonging to 3 classes.
# Found 2502 images belonging to 3 classes.
# Found 2502 images belonging to 3 classes.

# %%
classes = ['alert', 'microsleep', 'yawning']

# %%
class_count = np.unique(train_gen.classes, return_counts = True)

print("Class", class_count[0])
print("Count", class_count[1])
print()

plt.figure()

sns.barplot(x = classes, y = class_count[1])

plt.title("Training set is imbalance")
plt.xlabel('class')
plt.ylabel('count') 
plt.show()
# Out:
# Class [0 1 2]
# Count [35483  8074  4770]

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_gen.classes),
    y=train_gen.classes
)
class_labels = np.unique(train_gen.classes)
class_weight_dict = dict(zip(class_labels, class_weights))
class_weights
# Out:
# array([0.45399205, 1.99516968, 3.37714885])

# %%
class_weight_dict
# Out:
# {np.int32(0): np.float64(0.45399205253219854),
#  np.int32(1): np.float64(1.995169680455784),
#  np.int32(2): np.float64(3.377148846960168)}

# %%
fig, axes = plt.subplots(ncols = 5, nrows = 5)
axes =axes.flatten()

for i in range(25):
    j = np.random.randint(train_gen.n)

    # take data 
    batch_images, batch_labels = train_gen[j // BATCH_SIZE]
    id_in_batch = j % BATCH_SIZE 
    image = batch_images[id_in_batch]
    label = batch_labels[id_in_batch].argmax()

    # show data
    axes[i].imshow(image, cmap = "gray")
    axes[i].set_title(classes[label])
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(48,48,1)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.SpatialDropout2D(0.2),
    
    keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.SpatialDropout2D(0.2),
    
    keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.SpatialDropout2D(0.2),
    
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(3, activation='softmax')
])

optimizer = keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-4)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_3             │ (None, 24, 24, 32)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_4             │ (None, 12, 12, 64)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_5             │ (None, 6, 6, 128)      │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 489,443 (1.87 MB)
#  Trainable params: 487,011 (1.86 MB)
#  Non-trainable params: 2,432 (9.50 KB)

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
callbacks = [early_stopping, lr_scheduler]

# %%
model.fit(train_gen, epochs=100, validation_data=val_gen,class_weight=class_weight_dict, callbacks = callbacks)
# Out:
# Epoch 1/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 134s 87ms/step - accuracy: 0.6328 - loss: 0.6892 - val_accuracy: 0.6898 - val_loss: 0.8354 - learning_rate: 0.0010
# Epoch 2/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 137s 91ms/step - accuracy: 0.8613 - loss: 0.2793 - val_accuracy: 0.9133 - val_loss: 0.2107 - learning_rate: 0.0010
# Epoch 3/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 137s 90ms/step - accuracy: 0.9111 - loss: 0.1871 - val_accuracy: 0.9544 - val_loss: 0.1197 - learning_rate: 0.0010
# Epoch 4/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 137s 91ms/step - accuracy: 0.9301 - loss: 0.1500 - val_accuracy: 0.9085 - val_loss: 0.2666 - learning_rate: 0.0010
# Epoch 5/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 151s 100ms/step - accuracy: 0.9395 - loss: 0.1341 - val_accuracy: 0.9380 - val_loss: 0.1492 - learning_rate: 0.0010
# Epoch 6/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 142s 94ms/step - accuracy: 0.9444 - loss: 0.1201 - val_accuracy: 0.9069 - val_loss: 0.2828 - learning_rate: 0.0010
# Epoch 7/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 137s 91ms/step - accuracy: 0.9484 - loss: 0.1125 - val_accuracy: 0.9033 - val_loss: 0.2461 - learning_rate: 0.0010
# Epoch 8/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9529 - loss: 0.0972
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 135s 90ms/step - accuracy: 0.9517 - loss: 0.1004 - val_accuracy: 0.9001 - val_loss: 0.2487 - learning_rate: 0.0010
# Epoch 9/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 159s 105ms/step - accuracy: 0.9633 - loss: 0.0742 - val_accuracy: 0.9628 - val_loss: 0.0995 - learning_rate: 5.0000e-04
# Epoch 10/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 137s 91ms/step - accuracy: 0.9665 - loss: 0.0685 - val_accuracy: 0.9708 - val_loss: 0.0813 - learning_rate: 5.0000e-04
# Epoch 11/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 1750s 1s/step - accuracy: 0.9669 - loss: 0.0708 - val_accuracy: 0.9624 - val_loss: 0.0873 - learning_rate: 5.0000e-04
# Epoch 12/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 127s 84ms/step - accuracy: 0.9689 - loss: 0.0638 - val_accuracy: 0.9652 - val_loss: 0.0878 - learning_rate: 5.0000e-04
# Epoch 13/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 147s 97ms/step - accuracy: 0.9686 - loss: 0.0629 - val_accuracy: 0.9620 - val_loss: 0.1030 - learning_rate: 5.0000e-04
# Epoch 14/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 130s 86ms/step - accuracy: 0.9686 - loss: 0.0650 - val_accuracy: 0.9608 - val_loss: 0.0937 - learning_rate: 5.0000e-04
# Epoch 15/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 131s 87ms/step - accuracy: 0.9693 - loss: 0.0623 - val_accuracy: 0.9688 - val_loss: 0.0765 - learning_rate: 5.0000e-04
# Epoch 16/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 133s 88ms/step - accuracy: 0.9717 - loss: 0.0594 - val_accuracy: 0.9692 - val_loss: 0.0782 - learning_rate: 5.0000e-04
# Epoch 17/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 142s 94ms/step - accuracy: 0.9699 - loss: 0.0620 - val_accuracy: 0.9696 - val_loss: 0.0757 - learning_rate: 5.0000e-04
# Epoch 18/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 137s 90ms/step - accuracy: 0.9711 - loss: 0.0570 - val_accuracy: 0.9608 - val_loss: 0.0954 - learning_rate: 5.0000e-04
# Epoch 19/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 270s 179ms/step - accuracy: 0.9722 - loss: 0.0554 - val_accuracy: 0.9492 - val_loss: 0.1508 - learning_rate: 5.0000e-04
# Epoch 20/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 133s 88ms/step - accuracy: 0.9727 - loss: 0.0551 - val_accuracy: 0.9616 - val_loss: 0.1035 - learning_rate: 5.0000e-04
# Epoch 21/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 140s 92ms/step - accuracy: 0.9724 - loss: 0.0570 - val_accuracy: 0.9548 - val_loss: 0.1146 - learning_rate: 5.0000e-04
# Epoch 22/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9737 - loss: 0.0524
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 148s 98ms/step - accuracy: 0.9733 - loss: 0.0529 - val_accuracy: 0.9676 - val_loss: 0.0826 - learning_rate: 5.0000e-04
# Epoch 23/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9759 - loss: 0.0468 - val_accuracy: 0.9712 - val_loss: 0.0716 - learning_rate: 2.5000e-04
# Epoch 24/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 147s 97ms/step - accuracy: 0.9779 - loss: 0.0439 - val_accuracy: 0.9720 - val_loss: 0.0703 - learning_rate: 2.5000e-04
# Epoch 25/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 148s 98ms/step - accuracy: 0.9775 - loss: 0.0463 - val_accuracy: 0.9628 - val_loss: 0.0809 - learning_rate: 2.5000e-04
# Epoch 26/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 138s 92ms/step - accuracy: 0.9778 - loss: 0.0436 - val_accuracy: 0.9696 - val_loss: 0.0762 - learning_rate: 2.5000e-04
# Epoch 27/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9776 - loss: 0.0423 - val_accuracy: 0.9688 - val_loss: 0.0820 - learning_rate: 2.5000e-04
# Epoch 28/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 149s 99ms/step - accuracy: 0.9783 - loss: 0.0415 - val_accuracy: 0.9764 - val_loss: 0.0685 - learning_rate: 2.5000e-04
# Epoch 29/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 145s 96ms/step - accuracy: 0.9779 - loss: 0.0413 - val_accuracy: 0.9724 - val_loss: 0.0713 - learning_rate: 2.5000e-04
# Epoch 30/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 142s 94ms/step - accuracy: 0.9769 - loss: 0.0446 - val_accuracy: 0.9700 - val_loss: 0.0707 - learning_rate: 2.5000e-04
# Epoch 31/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 93ms/step - accuracy: 0.9786 - loss: 0.0413 - val_accuracy: 0.9744 - val_loss: 0.0657 - learning_rate: 2.5000e-04
# Epoch 32/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9782 - loss: 0.0412 - val_accuracy: 0.9748 - val_loss: 0.0725 - learning_rate: 2.5000e-04
# Epoch 33/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 94ms/step - accuracy: 0.9790 - loss: 0.0400 - val_accuracy: 0.9772 - val_loss: 0.0652 - learning_rate: 2.5000e-04
# Epoch 34/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9795 - loss: 0.0392 - val_accuracy: 0.9704 - val_loss: 0.0804 - learning_rate: 2.5000e-04
# Epoch 35/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 93ms/step - accuracy: 0.9793 - loss: 0.0385 - val_accuracy: 0.9712 - val_loss: 0.0796 - learning_rate: 2.5000e-04
# Epoch 36/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 143s 94ms/step - accuracy: 0.9786 - loss: 0.0398 - val_accuracy: 0.9768 - val_loss: 0.0693 - learning_rate: 2.5000e-04
# Epoch 37/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 93ms/step - accuracy: 0.9795 - loss: 0.0381 - val_accuracy: 0.9680 - val_loss: 0.0786 - learning_rate: 2.5000e-04
# Epoch 38/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9803 - loss: 0.0387
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 143s 94ms/step - accuracy: 0.9798 - loss: 0.0389 - val_accuracy: 0.9688 - val_loss: 0.0859 - learning_rate: 2.5000e-04
# Epoch 39/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 93ms/step - accuracy: 0.9800 - loss: 0.0372 - val_accuracy: 0.9704 - val_loss: 0.0712 - learning_rate: 1.2500e-04
# Epoch 40/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 94ms/step - accuracy: 0.9821 - loss: 0.0363 - val_accuracy: 0.9736 - val_loss: 0.0713 - learning_rate: 1.2500e-04
# Epoch 41/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 142s 94ms/step - accuracy: 0.9816 - loss: 0.0365 - val_accuracy: 0.9692 - val_loss: 0.0875 - learning_rate: 1.2500e-04
# Epoch 42/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 93ms/step - accuracy: 0.9806 - loss: 0.0359 - val_accuracy: 0.9756 - val_loss: 0.0620 - learning_rate: 1.2500e-04
# Epoch 43/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 142s 94ms/step - accuracy: 0.9815 - loss: 0.0342 - val_accuracy: 0.9748 - val_loss: 0.0708 - learning_rate: 1.2500e-04
# Epoch 44/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 93ms/step - accuracy: 0.9811 - loss: 0.0362 - val_accuracy: 0.9732 - val_loss: 0.0639 - learning_rate: 1.2500e-04
# Epoch 45/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 141s 93ms/step - accuracy: 0.9814 - loss: 0.0347 - val_accuracy: 0.9724 - val_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 46/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9818 - loss: 0.0345 - val_accuracy: 0.9724 - val_loss: 0.0676 - learning_rate: 1.2500e-04
# Epoch 47/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9817 - loss: 0.0366
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 148s 98ms/step - accuracy: 0.9823 - loss: 0.0342 - val_accuracy: 0.9744 - val_loss: 0.0646 - learning_rate: 1.2500e-04
# Epoch 48/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 145s 96ms/step - accuracy: 0.9817 - loss: 0.0347 - val_accuracy: 0.9720 - val_loss: 0.0669 - learning_rate: 6.2500e-05
# Epoch 49/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 147s 97ms/step - accuracy: 0.9818 - loss: 0.0323 - val_accuracy: 0.9768 - val_loss: 0.0632 - learning_rate: 6.2500e-05
# Epoch 50/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 147s 97ms/step - accuracy: 0.9827 - loss: 0.0328 - val_accuracy: 0.9768 - val_loss: 0.0593 - learning_rate: 6.2500e-05
# Epoch 51/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 146s 97ms/step - accuracy: 0.9826 - loss: 0.0313 - val_accuracy: 0.9736 - val_loss: 0.0692 - learning_rate: 6.2500e-05
# Epoch 52/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9824 - loss: 0.0329 - val_accuracy: 0.9664 - val_loss: 0.0768 - learning_rate: 6.2500e-05
# Epoch 53/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 146s 97ms/step - accuracy: 0.9832 - loss: 0.0318 - val_accuracy: 0.9748 - val_loss: 0.0687 - learning_rate: 6.2500e-05
# Epoch 54/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 143s 94ms/step - accuracy: 0.9821 - loss: 0.0325 - val_accuracy: 0.9752 - val_loss: 0.0761 - learning_rate: 6.2500e-05
# Epoch 55/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9831 - loss: 0.0311
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 146s 97ms/step - accuracy: 0.9834 - loss: 0.0306 - val_accuracy: 0.9756 - val_loss: 0.0631 - learning_rate: 6.2500e-05
# Epoch 56/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 151s 100ms/step - accuracy: 0.9832 - loss: 0.0316 - val_accuracy: 0.9760 - val_loss: 0.0581 - learning_rate: 3.1250e-05
# Epoch 57/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 202s 134ms/step - accuracy: 0.9836 - loss: 0.0313 - val_accuracy: 0.9728 - val_loss: 0.0731 - learning_rate: 3.1250e-05
# Epoch 58/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 138s 91ms/step - accuracy: 0.9840 - loss: 0.0302 - val_accuracy: 0.9748 - val_loss: 0.0656 - learning_rate: 3.1250e-05
# Epoch 59/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 155s 102ms/step - accuracy: 0.9835 - loss: 0.0315 - val_accuracy: 0.9740 - val_loss: 0.0741 - learning_rate: 3.1250e-05
# Epoch 60/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 150s 99ms/step - accuracy: 0.9845 - loss: 0.0318 - val_accuracy: 0.9752 - val_loss: 0.0661 - learning_rate: 3.1250e-05
# Epoch 61/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9829 - loss: 0.0316
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 149s 98ms/step - accuracy: 0.9838 - loss: 0.0308 - val_accuracy: 0.9748 - val_loss: 0.0651 - learning_rate: 3.1250e-05
# Epoch 62/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 149s 99ms/step - accuracy: 0.9845 - loss: 0.0289 - val_accuracy: 0.9720 - val_loss: 0.0748 - learning_rate: 1.5625e-05
# Epoch 63/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 145s 96ms/step - accuracy: 0.9837 - loss: 0.0311 - val_accuracy: 0.9736 - val_loss: 0.0759 - learning_rate: 1.5625e-05
# Epoch 64/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9833 - loss: 0.0320 - val_accuracy: 0.9748 - val_loss: 0.0723 - learning_rate: 1.5625e-05
# Epoch 65/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 146s 96ms/step - accuracy: 0.9845 - loss: 0.0292 - val_accuracy: 0.9748 - val_loss: 0.0718 - learning_rate: 1.5625e-05
# Epoch 66/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9836 - loss: 0.0292
# Epoch 66: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 199s 132ms/step - accuracy: 0.9834 - loss: 0.0306 - val_accuracy: 0.9756 - val_loss: 0.0660 - learning_rate: 1.5625e-05
# Epoch 67/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9830 - loss: 0.0306 - val_accuracy: 0.9752 - val_loss: 0.0682 - learning_rate: 7.8125e-06
# Epoch 68/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 147s 97ms/step - accuracy: 0.9843 - loss: 0.0307 - val_accuracy: 0.9716 - val_loss: 0.0740 - learning_rate: 7.8125e-06
# Epoch 69/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 146s 96ms/step - accuracy: 0.9836 - loss: 0.0315 - val_accuracy: 0.9740 - val_loss: 0.0710 - learning_rate: 7.8125e-06
# Epoch 70/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 146s 97ms/step - accuracy: 0.9843 - loss: 0.0299 - val_accuracy: 0.9712 - val_loss: 0.0762 - learning_rate: 7.8125e-06
# Epoch 71/100
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9837 - loss: 0.0301
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 165s 109ms/step - accuracy: 0.9839 - loss: 0.0299 - val_accuracy: 0.9728 - val_loss: 0.0703 - learning_rate: 7.8125e-06

# %%
model.save('fl3d_model_3.keras')

# %%
model.save('fl3d_model_whts_3.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from IPython.display import FileLink

# Provide the path to your saved model file
file_path = "/kaggle/working/fl3d_model_3.keras"

# Create a downloadable link
FileLink(file_path)
# Out:
# /kaggle/working/fl3d_model_3.keras

# %%
# Provide the path to your saved model file
file_path_2 = "/kaggle/working/fl3d_model_whts_3.h5"

# Create a downloadable link
FileLink(file_path_2)
# Out:
# /kaggle/working/fl3d_model_whts_3.h5

# %%
score = model.evaluate(test_gen, verbose=1)
print(f"Test loss: {score[0]:.4f}")
print(f"Test accuracy: {score[1]:.4f}")
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9836 - loss: 0.0462
# Test loss: 0.0462
# Test accuracy: 0.9836

# %%
pred_y = model.predict(test_gen)
pred_label = np.argmax(pred_y, axis=1)

true_label = test_gen.classes
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# %%
cfs_mt = confusion_matrix(true_label, pred_label)

plt.figure()

sns.heatmap(cfs_mt, annot = True, fmt = 'd')

plt.show()

# %%
print(classification_report(true_label, pred_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1728
#            1       0.98      0.94      0.96       416
#            2       0.99      0.99      0.99       358
#
#     accuracy                           0.98      2502
#    macro avg       0.98      0.98      0.98      2502
# weighted avg       0.98      0.98      0.98      2502

# %%
f1_scores = f1_score(true_label, pred_label, average=None)

f1_data = pd.DataFrame({
    'Class': classes,
    'F1-Score': f1_scores
})

# %%
f1_macro = f1_score(true_label, pred_label, average='macro')
print(f"F1-score macro: {f1_macro}")
# Out:
# F1-score macro: 0.9789130374811684

# %%
f1_data
# Out:
#         Class  F1-Score
# 0       alert  0.988174
# 1  microsleep  0.959707
# 2     yawning  0.988858

# %%
plt.figure()

sns.barplot(data=f1_data, x='Class', y='F1-Score')

plt.title('F1-Scores per Class')
plt.xticks(rotation=45)
plt.ylim(0, 1)

# add data label
for i, v in enumerate(f1_scores):
    plt.text(i, v + 0.01, f'{v:.3f}', ha='center')

plt.tight_layout()
plt.show()

# %%
# show 25 random test image and model predictions of them
fig, axes = plt.subplots(ncols = 5, nrows = 5, figsize = (15, 15))
axes =axes.flatten()

for i in range(25):
    j = np.random.randint(test_gen.n)

    # take data 
    batch_images, batch_labels = test_gen[j // BATCH_SIZE]
    id_in_batch = j % BATCH_SIZE 
    image = batch_images[id_in_batch]
    label = batch_labels[id_in_batch].argmax()

    # show data
    axes[i].imshow(image, cmap = "gray")
    axes[i].set_title(f"True label: {classes[label]}\nPredicted: {classes[pred_label[j]]}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()
